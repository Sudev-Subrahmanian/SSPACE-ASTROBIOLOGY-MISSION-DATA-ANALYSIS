# %%
import numpy as np
import matplotlib.pyplot as plt

# Original Data
y_values = [0.093, 0.106, 0.106, 0.1, 0.105, 0.114, 0.108, 0.159, 0.769, 0.929,
            1.022, 1.097, 1.156, 1.205, 1.243, 1.29, 1.31, 1.36, 1.63, 1.631,
            1.632, 1.364, 1.352, 1.486, 1.406, 1.428, 1.644, 1.421, 1.442]

x_values = [0, 41, 75, 120, 163, 240, 285, 320, 419, 450,
            490, 540, 575, 610, 650, 720, 770, 805, 845, 896,
            930, 1003, 1052, 1095, 1124, 1166, 1212, 1270, 1310]

# Regularizing the x-axis by sampling at regular intervals
x_new = np.linspace(min(x_values), max(x_values), num=50)  # 50 evenly spaced points
y_interpolated = np.interp(x_new, x_values, y_values)  # Interpolating y-values

# Applying a moving average with a window size of 5
window_size = 5
y_smooth = np.convolve(y_interpolated, np.ones(window_size)/window_size, mode='valid')

# Adjust x to match the moving average output
x_smooth = x_new[:len(y_smooth)]

# Plot the original and smoothed data
plt.figure(figsize=(8, 5))
plt.plot(x_values, y_values, 'bo', alpha=0.5, label="Original Data")  # Original points
plt.plot(x_smooth, y_smooth, 'r-', linewidth=2, label="Smoothed Data")  # Smoothed curve

# Labels and Title
plt.xlabel("X Values (Regularized)")
plt.ylabel("Y Values (Smoothed)")
plt.title("Regularized and Smoothed Data Plot")
plt.legend()
plt.grid(True)

# Show Plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original Data
y_values = [0.093, 0.106, 0.106, 0.1, 0.105, 0.114, 0.108, 0.159, 0.769, 0.929,
            1.022, 1.097, 1.156, 1.205, 1.243, 1.29, 1.31, 1.36, 1.63, 1.631,
            1.632, 1.364, 1.352, 1.486, 1.406, 1.428, 1.644, 1.421, 1.442]

x_values = [0, 41, 75, 120, 163, 240, 285, 320, 419, 450,
            490, 540, 575, 610, 650, 720, 770, 805, 845, 896,
            930, 1003, 1052, 1095, 1124, 1166, 1212, 1270, 1310]

# Regularizing the x-axis by sampling at regular intervals
x_new = np.linspace(min(x_values), max(x_values), num=50)  # 50 evenly spaced points
y_interpolated = np.interp(x_new, x_values, y_values)  # Interpolating y-values

# Applying a moving average with a window size of 5
window_size = 5
y_smooth = np.convolve(y_interpolated, np.ones(window_size)/window_size, mode='valid')

# Adjust x to match the moving average output
x_smooth = x_new[:len(y_smooth)]

# Compute derivative dy/dx
dy_dx = np.gradient(y_smooth, x_smooth)

# Plot dy/dx vs x
plt.figure(figsize=(8, 5))
plt.plot(x_smooth, dy_dx, 'g-', linewidth=2, label="dy/dx vs X")
plt.xlabel("X Values (Regularized)")
plt.ylabel("Derivative (dy/dx)")
plt.title("Derivative of Smoothed Data wrt X")
plt.grid(True)
plt.legend()
plt.show()

# Plot dy/dx vs y_smooth
plt.figure(figsize=(8, 5))
plt.plot(y_smooth, dy_dx, 'm-', linewidth=2, label="dy/dx vs Y")
plt.xlabel("Y Values (Smoothed)")
plt.ylabel("Derivative (dy/dx)")
plt.title("Derivative of Smoothed Data wrt Y")
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original Data
y_values = [0.093, 0.106, 0.106, 0.1, 0.105, 0.114, 0.108, 0.159, 0.769, 0.929,
            1.022, 1.097, 1.156, 1.205]

x_values = [0, 41, 75, 120, 163, 240, 285, 320, 419, 450,
            490, 540, 575, 610]

# Regularizing the x-axis by sampling at regular intervals
x_new = np.linspace(min(x_values), max(x_values), num=50)  # 50 evenly spaced points
y_interpolated = np.interp(x_new, x_values, y_values)  # Interpolating y-values

# Applying a moving average with a window size of 5
window_size = 5
y_smooth = np.convolve(y_interpolated, np.ones(window_size)/window_size, mode='valid')

# Adjust x to match the moving average output
x_smooth = x_new[:len(y_smooth)]

# Compute derivative dy/dx
dy_dx = np.gradient(y_smooth, x_smooth)

# Plot dy/dx vs x
plt.figure(figsize=(8, 5))
plt.plot(x_smooth, dy_dx, 'g-', linewidth=2, label="dy/dx vs X")
plt.xlabel("X Values (Regularized)")
plt.ylabel("Derivative (dy/dx)")
plt.title("Derivative of Smoothed Data wrt X")
plt.grid(True)
plt.legend()
plt.show()

# Plot dy/dx vs y_smooth
plt.figure(figsize=(8, 5))
plt.plot(y_smooth, dy_dx, 'm-', linewidth=2, label="dy/dx vs Y")
plt.xlabel("Y Values (Smoothed)")
plt.ylabel("Derivative (dy/dx)")
plt.title("Derivative of Smoothed Data wrt Y")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### changes by Aryan

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original Data
y_values = [0.093, 0.106, 0.106, 0.1, 0.105, 0.114, 0.108, 0.159, 0.769]
x_values = [0, 41, 75, 120, 163, 240, 285, 320, 419]

# Regularizing the x-axis by sampling at regular intervals
x_new = np.linspace(min(x_values), max(x_values), num=50)  # 50 evenly spaced points
y_interpolated = np.interp(x_new, x_values, y_values)  # Interpolating y-values

# Applying a moving average with a window size of 1
window_size = 1
y_smooth = np.convolve(y_interpolated, np.ones(window_size)/window_size, mode='valid')

# Adjust x to match the moving average output
x_smooth = x_new[:len(y_smooth)]

# Compute derivative dy/dx
dy_dx = np.gradient(y_smooth, x_smooth)

# Plot y vs x
plt.figure(figsize=(8, 5))
plt.plot(x_smooth, y_smooth, 'b-', linewidth=2, label="Y vs X")
plt.scatter(x_smooth, y_smooth, color='red', label="Interpolated Points", zorder=3)
plt.xlabel("X Values (Regularized)")
plt.ylabel("Y Values (Smoothed)")
plt.title("Y vs X")
plt.grid(True)
plt.legend()
plt.show()

# Plot dy/dx vs x
plt.figure(figsize=(8, 5))
plt.plot(x_smooth, dy_dx, 'g-', linewidth=2, label="dy/dx vs X")
plt.scatter(x_smooth, dy_dx, color='red', label="Computed Points", zorder=3)
plt.xlabel("X Values (Regularized)")
plt.ylabel("Derivative (dy/dx)")
plt.title("Derivative of Smoothed Data wrt X")
plt.grid(True)
plt.legend()
plt.show()

# Plot dy/dx vs y_smooth
plt.figure(figsize=(8, 5))
plt.plot(y_smooth, dy_dx, 'm-', linewidth=2, label="dy/dx vs Y")
plt.scatter(y_smooth, dy_dx, color='blue', label="Computed Points", zorder=3)
plt.xlabel("Y Values (Smoothed)")
plt.ylabel("Derivative (dy/dx)")
plt.title("Derivative of Smoothed Data wrt Y")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### MAX plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original Data
y_values = [0.093, 0.106, 0.106, 0.1, 0.105, 0.114, 0.108, 0.159, 0.769]
x_values = [0, 41, 75, 120, 163, 240, 285, 320, 419]

# Regularizing the x-axis by sampling at regular intervals
x_new = np.linspace(min(x_values), max(x_values), num=50)  # 50 evenly spaced points
y_interpolated = np.interp(x_new, x_values, y_values)  # Interpolating y-values

# Applying a moving average with a window size of 1
window_size = 1
y_smooth = np.convolve(y_interpolated, np.ones(window_size)/window_size, mode='valid')

# Adjust x to match the moving average output
x_smooth = x_new[:len(y_smooth)]

# Compute cumulative max transformation
y_smooth_max = np.maximum.accumulate(y_smooth)  # Running max for y
x_smooth_max = np.maximum.accumulate(x_smooth)  # Running max for x

# Compute derivative dy/dx for transformed data
dy_dx_max = np.gradient(y_smooth_max, x_smooth_max)

# Plot transformed Y vs X
plt.figure(figsize=(8, 5))
plt.plot(x_smooth_max, y_smooth_max, 'b-', linewidth=2, label="Transformed Y vs X")
plt.scatter(x_smooth_max, y_smooth_max, color='red', label="Transformed Points", zorder=3)
plt.xlabel("X Values (Cumulative Max)")
plt.ylabel("Y Values (Cumulative Max)")
plt.title("Transformed Y vs X (Cumulative Max)")
plt.grid(True)
plt.legend()
plt.show()

# Plot dy/dx vs x (transformed)
plt.figure(figsize=(8, 5))
plt.plot(x_smooth_max, dy_dx_max, 'g-', linewidth=2, label="dy/dx vs X (Transformed)")
plt.scatter(x_smooth_max, dy_dx_max, color='red', label="Computed Points", zorder=3)
plt.xlabel("X Values (Cumulative Max)")
plt.ylabel("Derivative (dy/dx)")
plt.title("Derivative of Transformed Data wrt X")
plt.grid(True)
plt.legend()
plt.show()

# Plot dy/dx vs y_smooth (transformed)
plt.figure(figsize=(8, 5))
plt.plot(y_smooth_max, dy_dx_max, 'm-', linewidth=2, label="dy/dx vs Y (Transformed)")
plt.scatter(y_smooth_max, dy_dx_max, color='blue', label="Computed Points", zorder=3)
plt.xlabel("Y Values (Cumulative Max)")
plt.ylabel("Derivative (dy/dx)")
plt.title("Derivative of Transformed Data wrt Y")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### OLD DATA

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original Data
y_values = []
x_values = []

# Regularizing the x-axis by sampling at regular intervals
x_new = np.linspace(min(x_values), max(x_values), num=50)  # 50 evenly spaced points
y_interpolated = np.interp(x_new, x_values, y_values)  # Interpolating y-values

# Applying a moving average with a window size of 1
window_size = 1
y_smooth = np.convolve(y_interpolated, np.ones(window_size)/window_size, mode='valid')

# Adjust x to match the moving average output
x_smooth = x_new[:len(y_smooth)]

# Compute cumulative max transformation
y_smooth_max = np.maximum.accumulate(y_smooth)  # Running max for y
x_smooth_max = np.maximum.accumulate(x_smooth)  # Running max for x

# Compute derivative dy/dx for transformed data
dy_dx_max = np.gradient(y_smooth_max, x_smooth_max)

# Plot transformed Y vs X
plt.figure(figsize=(8, 5))
plt.plot(x_smooth_max, y_smooth_max, 'b-', linewidth=2, label="Transformed Y vs X")
plt.scatter(x_smooth_max, y_smooth_max, color='red', label="Transformed Points", zorder=3)
plt.xlabel("X Values (Cumulative Max)")
plt.ylabel("Y Values (Cumulative Max)")
plt.title("Transformed Y vs X (Cumulative Max)")
plt.grid(True)
plt.legend()
plt.show()

# Plot dy/dx vs x (transformed)
plt.figure(figsize=(8, 5))
plt.plot(x_smooth_max, dy_dx_max, 'g-', linewidth=2, label="dy/dx vs X (Transformed)")
plt.scatter(x_smooth_max, dy_dx_max, color='red', label="Computed Points", zorder=3)
plt.xlabel("X Values (Cumulative Max)")
plt.ylabel("Derivative (dy/dx)")
plt.title("Derivative of Transformed Data wrt X")
plt.grid(True)
plt.legend()
plt.show()

# Plot dy/dx vs y_smooth (transformed)
plt.figure(figsize=(8, 5))
plt.plot(y_smooth_max, dy_dx_max, 'm-', linewidth=2, label="dy/dx vs Y (Transformed)")
plt.scatter(y_smooth_max, dy_dx_max, color='blue', label="Computed Points", zorder=3)
plt.xlabel("Y Values (Cumulative Max)")
plt.ylabel("Derivative (dy/dx)")
plt.title("Derivative of Transformed Data wrt Y")
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import datetime

# Given Data
data = {
    "6/11/24": [
        ("10:55", 0.092), ("11:40", 0.096), ("12:16", 0.098), ("12:45", 0.097),
        ("13:20", 0.098), ("14:04", 0.098), ("14:35", 0.099), ("15:10", 0.099),
        ("15:45", 0.112), ("16:30", 0.107), ("17:09", 0.126), ("17:43", 0.166),
        ("18:09", 0.512), ("18:55", 0.624), ("19:30", 0.93), ("20:34", 1.006),
        ("21:06", 1.317), ("21:30", 1.374), ("22:00", 1.12), ("22:41", 1.413),
        ("23:14", 1.47), ("01:00", 1.339), ("01:30", 1.349)
    ],
    "7/11/24": [
        ("14:10", 0.093), ("14:51", 0.106), ("15:25", 0.106), ("16:10", 0.1),
        ("16:53", 0.105), ("18:10", 0.114), ("18:55", 0.108), ("20:35", 0.191),
        ("21:05", 0.159), ("22:37", 0.968), ("23:10", 1.091), ("23:44", 1.287),
        ("00:18", 1.316), ("01:36", 1.366), ("02:10", 1.349)
    ],
    "11/11/24": [
        ("11:41", 0.089), ("12:18", 0.096), ("13:15", 0.098), ("13:50", 0.099),
        ("14:30", 0.093), ("14:55", 0.095), ("15:34", 0.103), ("16:14", 0.096),
        ("16:45", 0.098), ("17:10", 0.101), ("18:00", 0.105), ("18:45", 0.176),
        ("19:45", 0.39), ("20:25", 0.794), ("21:06", 1.072), ("21:45", 1.208),
        ("22:19", 1.301), ("22:45", 1.362), ("23:25", 1.404), ("00:10", 1.367),
        ("00:45", 1.386), ("01:10", 1.428), ("01:45", 1.477)
    ],
    "12/11/24": [
        ("11:55", 0.09), ("12:28", 0.097), ("12:50", 0.091), ("14:45", 0.098),
        ("15:20", 0.091), ("15:56", 0.096), ("16:27", 0.097), ("18:00", 0.151),
        ("18:51", 0.116), ("19:32", 0.179), ("20:06", 0.331), ("20:42", 0.647),
        ("21:15", 0.947), ("21:45", 1.061), ("22:20", 1.134), ("22:54", 1.19),
        ("23:25", 1.275), ("00:25", 1.339), ("01:00", 1.425), ("01:30", 1.48),
        ("02:00", 1.541)
    ],
    "13/11/24": [
        ("12:05", 0.089), ("12:40", 0.097), ("13:15", 0.086), ("13:40", 0.095),
        ("14:20", 0.091), ("14:50", 0.091), ("15:35", 0.091), ("16:10", 0.095),
        ("18:00", 0.146), ("18:50", 0.111), ("19:34", 0.15), ("20:07", 0.305),
        ("20:40", 0.633), ("21:15", 0.918), ("21:44", 1.058), ("22:15", 1.15),
        ("22:48", 1.235), ("23:18", 1.302), ("00:20", 1.385), ("00:55", 1.439),
        ("01:30", 1.469), ("02:00", 1.515), ("11:49", 1.124), ("12:25", 1.142),
        ("13:18", 1.193), ("13:45", 1.213), ("14:20", 1.169), ("15:10", 1.196)
    ]
}

# Function to convert time to minutes since the first recorded time of the day
def convert_time_to_minutes(times):
    base_time = datetime.datetime.strptime(times[0], "%H:%M")
    return [(datetime.datetime.strptime(t, "%H:%M") - base_time).seconds / 60 for t in times]

# Process and plot data for each day
for date, values in data.items():
    times, absorbance = zip(*values)
    x_values = convert_time_to_minutes(times)
    y_values = np.array(absorbance)

    # Regularize x-axis
    x_new = np.linspace(min(x_values), max(x_values), num=50)
    y_interpolated = np.interp(x_new, x_values, y_values)

    # Moving average
    window_size = 3  # Slight smoothing
    y_smooth = np.convolve(y_interpolated, np.ones(window_size)/window_size, mode='valid')
    x_smooth = x_new[:len(y_smooth)]

    # Cumulative max transformation
    y_smooth_max = np.maximum.accumulate(y_smooth)
    x_smooth_max = np.maximum.accumulate(x_smooth)

    # Compute derivative dy/dx
    dy_dx_max = np.gradient(y_smooth_max, x_smooth_max)

    # Plot Transformed Y vs X
    plt.figure(figsize=(8, 5))
    plt.plot(x_smooth_max, y_smooth_max, 'b-', linewidth=2, label="Transformed Y vs X")
    plt.scatter(x_smooth_max, y_smooth_max, color='red', label="Transformed Points", zorder=3)
    plt.xlabel("X Values (Cumulative Max)")
    plt.ylabel("Y Values (Cumulative Max)")
    plt.title(f"Transformed Y vs X - {date}")
    plt.grid(True)
    plt.legend()
    plt.show()

    # Plot dy/dx vs x (transformed)
    plt.figure(figsize=(8, 5))
    plt.plot(x_smooth_max, dy_dx_max, 'g-', linewidth=2, label="dy/dx vs X (Transformed)")
    plt.scatter(x_smooth_max, dy_dx_max, color='red', label="Computed Points", zorder=3)
    plt.xlabel("X Values (Cumulative Max)")
    plt.ylabel("Derivative (dy/dx)")
    plt.title(f"Derivative of Transformed Data wrt X - {date}")
    plt.grid(True)
    plt.legend()
    plt.show()

    # Plot dy/dx vs y_smooth (transformed)
    plt.figure(figsize=(8, 5))
    plt.plot(y_smooth_max, dy_dx_max, 'm-', linewidth=2, label="dy/dx vs Y (Transformed)")
    plt.scatter(y_smooth_max, dy_dx_max, color='blue', label="Computed Points", zorder=3)
    plt.xlabel("Y Values (Cumulative Max)")
    plt.ylabel("Derivative (dy/dx)")
    plt.title(f"Derivative of Transformed Data wrt Y - {date}")
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
from scipy.stats import linregress

# Dictionary to store fit results
fit_results = {}

# Process and plot data for each day with x values limited to 240 minutes
for date, values in data.items():
    times, absorbance = zip(*values)
    x_values = convert_time_to_minutes(times)
    y_values = np.array(absorbance)



    if len(x_values) < 2:  # Ensure enough data points remain
        continue

    # Regularize x-axis
    x_new = np.linspace(min(x_values), max(x_values), num=50)
    y_interpolated = np.interp(x_new, x_values, y_values)

    # Moving average
    window_size = 3
    y_smooth = np.convolve(y_interpolated, np.ones(window_size)/window_size, mode='valid')
    x_smooth = x_new[:len(y_smooth)]

    # Cumulative max transformation
    y_smooth_max = np.maximum.accumulate(y_smooth)
    x_smooth_max = np.maximum.accumulate(x_smooth)

    # Filter x values below 240 minutes
    mask = np.array(x_smooth_max) < 240
    x_smooth_max = np.array(x_smooth_max)[mask]
    y_smooth_max = y_smooth_max[mask]

    # Compute derivative dy/dx
    dy_dx_max = np.gradient(y_smooth_max, x_smooth_max)

    # Perform linear fit of dy/dx vs y_smooth_max
    slope, intercept, r_value, p_value, std_err = linregress(y_smooth_max, dy_dx_max)
    fit_results[date] = (slope, intercept)

    # Plot dy/dx vs y_smooth (transformed) with linear fit
    plt.figure(figsize=(8, 5))
    plt.plot(y_smooth_max, dy_dx_max, 'mo', label="Computed Points")
    plt.plot(y_smooth_max, slope * np.array(y_smooth_max) + intercept, 'r-', linewidth=2, label=f"Fit: y = {slope:.4f}x + {intercept:.4f}")
    plt.xlabel("Y Values (Cumulative Max)")
    plt.ylabel("Derivative (dy/dx)")
    plt.title(f"Linear Fit of dy/dx vs Y - {date}")
    plt.grid(True)
    plt.legend()
    plt.show()

# Display fit results in tabular format
import pandas as pd
fit_df = pd.DataFrame.from_dict(fit_results, orient='index', columns=['Slope', 'Intercept'])
fit_df
# Out:
#              Slope  Intercept
# 6/11/24  -0.004926   0.000515
# 7/11/24  -0.013396   0.001498
# 11/11/24 -0.017353   0.001733
# 12/11/24 -0.003448   0.000345
# 13/11/24  0.003681   0.002532

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original Data
y_values = [0.093, 0.106, 0.106, 0.1, 0.105, 0.114, 0.108, 0.159, 0.769]
x_values = [0, 41, 75, 120, 163, 240, 285, 320, 419]

# Regularizing the x-axis by sampling at regular intervals
x_new = np.linspace(min(x_values), max(x_values), num=50)  # 50 evenly spaced points
y_interpolated = np.interp(x_new, x_values, y_values)  # Interpolating y-values

# Applying a moving average with a window size of 1
window_size = 1
y_smooth = np.convolve(y_interpolated, np.ones(window_size)/window_size, mode='valid')

# Adjust x to match the moving average output
x_smooth = x_new[:len(y_smooth)]

# Compute cumulative max transformation
y_smooth_max = np.maximum.accumulate(y_smooth)  # Running max for y
x_smooth_max = np.maximum.accumulate(x_smooth)  # Running max for x

# Compute derivative dy/dx for transformed data
dy_dx_max = np.gradient(y_smooth_max, x_smooth_max)

# Plot transformed Y vs X
plt.figure(figsize=(8, 5))
plt.plot(x_smooth_max, y_smooth_max, 'b-', linewidth=2, label="Transformed Y vs X")
plt.scatter(x_smooth_max, y_smooth_max, color='red', label="Transformed Points", zorder=3)
plt.xlabel("X Values (Cumulative Max)")
plt.ylabel("Y Values (Cumulative Max)")
plt.title("Transformed Y vs X (Cumulative Max)")
plt.grid(True)
plt.legend()
plt.show()

# Plot dy/dx vs x (transformed)
plt.figure(figsize=(8, 5))
plt.plot(x_smooth_max, dy_dx_max, 'g-', linewidth=2, label="dy/dx vs X (Transformed)")
plt.scatter(x_smooth_max, dy_dx_max, color='red', label="Computed Points", zorder=3)
plt.xlabel("X Values (Cumulative Max)")
plt.ylabel("Derivative (dy/dx)")
plt.title("Derivative of Transformed Data wrt X")
plt.grid(True)
plt.legend()
plt.show()

# Plot dy/dx vs y_smooth (transformed)
plt.figure(figsize=(8, 5))
plt.plot(y_smooth_max, dy_dx_max, 'm-', linewidth=2, label="dy/dx vs Y (Transformed)")
plt.scatter(y_smooth_max, dy_dx_max, color='blue', label="Computed Points", zorder=3)
plt.xlabel("Y Values (Cumulative Max)")
plt.ylabel("Derivative (dy/dx)")
plt.title("Derivative of Transformed Data wrt Y")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plot dy/dx vs y_smooth (transformed) with linear fit
plt.figure(figsize=(8, 5))
plt.plot(y_smooth_max, dy_dx_max, 'mo', label="Computed Points")
plt.plot(y_smooth_max, slope * np.array(y_smooth_max) + intercept, 'r-', linewidth=2,
         label=f"Fit: y = {slope:.4f}x + {intercept:.4f}")
plt.xlabel("Y Values (Cumulative Max)")
plt.ylabel("Derivative (dy/dx)")
plt.title("Linear Fit of dy/dx vs Y")
plt.grid(True)
plt.legend()
plt.show()

# Equation of the line
line_eqn = f"y = {slope:.4f}x + {intercept:.4f}"
line_eqn
# Out:
# 'y = 0.0122x + -0.0008'
